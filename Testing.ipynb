# %%
! pip install pydrive 
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
local_download_path = os.path.expanduser('~/data')
try:
  os.makedirs(local_download_path)
except: pass
from google.colab import drive
drive.mount('/content/drive/',force_remount=True)
# Out:
# Requirement already satisfied: pydrive in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from pydrive) (1.7.11)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pydrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from pydrive) (3.13)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive) (0.11.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive) (3.0.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive) (0.0.3)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive) (1.12.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive) (1.7.2)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (4.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (0.4.8)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->pydrive) (3.1.1)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->pydrive) (45.1.0)
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# %cd 'drive/My Drive'
# Out:
# /content/drive/My Drive

# %%
# %cd darknet
# Out:
# /content/drive/My Drive/darknet

# %%
# %ls
# Out:
# 3rdparty/     CMakeLists.txt          include/               scripts/
# appveyor.yml  darknet                 json_mjpeg_streams.sh  src/
# backup/       darknet53.conv.74       LICENSE                valid.txt
# bad.list      DarknetConfig.cmake.in  Makefile               video_v2.sh
# build/        darknet.py              net_cam_v3.sh          video_yolov3.sh
# build.ps1     darknet_video.py        obj/                   yolo-obj.cfg
# build.sh      data/                   output.log
# cfg/          image_yolov2.sh         README.md
# cmake/        image_yolov3.sh         results/

# %%
# %ls
# Out:
# 3rdparty/          DarknetConfig.cmake.in  output.log
# appveyor.yml       darknet.py              README.md
# backup/            darknet_video.py        results/
# bad.list           data/                   scripts/
# build/             image_yolov2.sh         src/
# build.ps1          image_yolov3.sh         valid.txt
# build.sh           include/                video_v2.sh
# cfg/               json_mjpeg_streams.sh   video_yolov3.sh
# cmake/             LICENSE                 yolo-obj.cfg
# CMakeLists.txt     Makefile                yolo-obj_final_vehicle.weights
# darknet            net_cam_v3.sh
# darknet53.conv.74  obj/

# %%
# %cd ..
# Out:
# /content/drive/My Drive

# %%
# !apt-get update > /dev/null
# !apt-get upgrade > /dev/null
# !apt-get install build-essential > /dev/null
# !apt-get install cmake git libgtk2.0-dev pkg-config libavcodec-dev libavformat-dev libswscale-dev > /dev/null
# !apt-get install libopencv-dev > /dev/null
# !apt-get install libavcodec-dev libavformat-dev libswscale-d > /dev/null
# Out:
# Extracting templates from packages: 100%
# Extracting templates from packages: 100%
# E: Unable to locate package libswscale-d

# %%
# %cd darknet
# Out:
# /content/drive/My Drive/darknet

# %%
# !sed -i 's/OPENCV=1/OPENCV=0/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/g' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/g' Makefile

# !make
# !apt install g++-5
# !apt install gcc-5
# !apt update
# !apt upgrade
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:247:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2039:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2038:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:264:40: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                       ~~^
#                                       %Ilu
#              size / (1024*1024), num_of_blocks, pinned_block_size / (1024 * 1024));
#              ~~~~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:264:64: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                               ~~^
#                                                               %Ilu
# ./src/dark_cuda.c:264:82: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                                                 ~~^
#                                                                                 %Ilu
# ./src/dark_cuda.c:274:37: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#                  printf(" Allocated %d pinned block \n", pinned_block_size);
#                                     ~^
#                                     %ld
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:295:43: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#              printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#                                           ~^
#                                           %ld
# ./src/dark_cuda.c:310:64: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#                                                                ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                                %ld
# ./src/dark_cuda.c:316:63: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#                                                               ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                               %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1204:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:73:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:73:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:73:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:73:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:73:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:281:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:281:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:205:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#                  int out_index = id;
#                      ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1272:19: warning: unused variable ‘scale’ [-Wunused-variable]
#              float scale = rand_precalc_random(.25, 2, r_scale); // unused currently
#                    ^~~~~
# ./src/data.c:1272:19: warning: ‘r_scale’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#              float scale = rand_precalc_random(.25, 2, r_scale); // unused currently
#                    ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:591:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:39,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:337:11: warning: unused variable ‘one’ [-Wunused-variable]
#      float one = 1;    // alpha[0], beta[0]
#            ^~~
# ./src/connected_layer.c:335:13: warning: unused variable ‘c’ [-Wunused-variable]
#      float * c = l.output_gpu;
#              ^
# ./src/connected_layer.c:334:13: warning: unused variable ‘b’ [-Wunused-variable]
#      float * b = l.weights_gpu;
#              ^
# ./src/connected_layer.c:333:13: warning: unused variable ‘a’ [-Wunused-variable]
#      float * a = state.input;
#              ^
# ./src/connected_layer.c:332:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = l.outputs;
#          ^
# ./src/connected_layer.c:331:9: warning: unused variable ‘k’ [-Wunused-variable]
#      int k = l.inputs;
#          ^
# ./src/connected_layer.c:330:9: warning: unused variable ‘m’ [-Wunused-variable]
#      int m = l.batch;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1443:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:886:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#                      float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~
# ./src/box.c:885:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#                      float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#      char *base = "results/comp4_det_test_";
#            ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘train_detector’:
# ./src/detector.c:267:13: warning: variable ‘draw_precision’ set but not used [-Wunused-but-set-variable]
#          int draw_precision = 0;
#              ^~~~~~~~~~~~~~
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:484:21: warning: statement with no effect [-Wunused-value]
#                      for (k; buf[k + n] != '\0'; k++)
#                      ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:595:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#          int mkd2 = make_directory(buff2, 0777);
#              ^~~~
# ./src/detector.c:593:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#          int mkd = make_directory(buff, 0777);
#              ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1214:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1213:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:191:9: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#          if (l.x_gpu)                   cuda_free(l.x_gpu);  l.x_gpu = NULL;
#          ^~
# ./src/layer.c:191:61: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#          if (l.x_gpu)                   cuda_free(l.x_gpu);  l.x_gpu = NULL;
#                                                              ^
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:175:13: warning: variable ‘draw_precision’ set but not used [-Wunused-but-set-variable]
#          int draw_precision = 0;
#              ^~~~~~~~~~~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:818:13: warning: unused variable ‘time’ [-Wunused-variable]
#      clock_t time;
#              ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#          float scale = sqrt(2. / l.nweights);
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/demo.c -o obj/demo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/region_layer.c -o obj/region_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:61:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:68:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:95:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:104:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘forward_yolo_layer’:
# ./src/yolo_layer.c:359:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#                      int best_match_t = 0;
#                          ^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/gaussian_yolo_layer.c -o obj/gaussian_yolo_layer.o
# ./src/gaussian_yolo_layer.c: In function ‘make_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:71:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:39,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:78:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:39,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:110:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:39,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:119:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:39,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c: In function ‘forward_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:453:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#                      int best_match_t = 0;
#                          ^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# ./src/blas_kernels.cu(957): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(983): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1594): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(957): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(983): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1594): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(957): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(983): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1594): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(957): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(983): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1594): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(957): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(983): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1594): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(957): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(983): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1594): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu: In function ‘void backward_shortcut_multilayer_gpu(int, int, int, int*, float**, float*, float*, float*, float*, int, float*, float**, WEIGHTS_NORMALIZATION_T)’:
# ./src/blas_kernels.cu:983:5: warning: variable ‘step’ set but not used [-Wunused-but-set-variable]
#      int step = 0;
#      ^~~~
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# ./src/dropout_layer_kernels.cu(26): warning: variable "index" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(118): warning: variable "max_blocks_per_channel" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(26): warning: variable "index" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(118): warning: variable "max_blocks_per_channel" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(26): warning: variable "index" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(118): warning: variable "max_blocks_per_channel" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(26): warning: variable "index" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(118): warning: variable "max_blocks_per_channel" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(26): warning: variable "index" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(118): warning: variable "max_blocks_per_channel" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(26): warning: variable "index" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(118): warning: variable "max_blocks_per_channel" was declared but never referenced
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   cpp-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# Suggested packages:
#   gcc-5-locales g++-5-multilib gcc-5-doc libstdc++6-5-dbg gcc-5-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan2-dbg
#   liblsan0-dbg libtsan0-dbg libubsan0-dbg libcilkrts5-dbg libmpx0-dbg
#   libquadmath0-dbg libstdc++-5-doc
# The following NEW packages will be installed:
#   cpp-5 g++-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# 0 upgraded, 9 newly installed, 0 to remove and 7 not upgraded.
# Need to get 29.1 MB of archives.
# After this operation, 100 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5-base amd64 5.5.0-12ubuntu1 [17.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libisl15 amd64 0.18-4 [548 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 cpp-5 amd64 5.5.0-12ubuntu1 [7,785 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libasan2 amd64 5.5.0-12ubuntu1 [264 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmpx0 amd64 5.5.0-12ubuntu1 [9,888 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgcc-5-dev amd64 5.5.0-12ubuntu1 [2,224 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5 amd64 5.5.0-12ubuntu1 [8,357 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libstdc++-5-dev amd64 5.5.0-12ubuntu1 [1,415 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 g++-5 amd64 5.5.0-12ubuntu1 [8,450 kB]
# Fetched 29.1 MB in 0s (62.4 MB/s)
# Selecting previously unselected package gcc-5-base:amd64.
# (Reading database ... 147174 files and directories currently installed.)
# Preparing to unpack .../0-gcc-5-base_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking gcc-5-base:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libisl15:amd64.
# Preparing to unpack .../1-libisl15_0.18-4_amd64.deb ...
# Unpacking libisl15:amd64 (0.18-4) ...
# Selecting previously unselected package cpp-5.
# Preparing to unpack .../2-cpp-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking cpp-5 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libasan2:amd64.
# Preparing to unpack .../3-libasan2_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libasan2:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libmpx0:amd64.
# Preparing to unpack .../4-libmpx0_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libmpx0:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libgcc-5-dev:amd64.
# Preparing to unpack .../5-libgcc-5-dev_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libgcc-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package gcc-5.
# Preparing to unpack .../6-gcc-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking gcc-5 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libstdc++-5-dev:amd64.
# Preparing to unpack .../7-libstdc++-5-dev_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libstdc++-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package g++-5.
# Preparing to unpack .../8-g++-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking g++-5 (5.5.0-12ubuntu1) ...
# Setting up libisl15:amd64 (0.18-4) ...
# Setting up gcc-5-base:amd64 (5.5.0-12ubuntu1) ...
# Setting up libmpx0:amd64 (5.5.0-12ubuntu1) ...
# Setting up libasan2:amd64 (5.5.0-12ubuntu1) ...
# Setting up libgcc-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Setting up cpp-5 (5.5.0-12ubuntu1) ...
# Setting up libstdc++-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Setting up gcc-5 (5.5.0-12ubuntu1) ...
# Setting up g++-5 (5.5.0-12ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# gcc-5 is already the newest version (5.5.0-12ubuntu1).
# gcc-5 set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# Hit:1 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:3 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:8 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease
# Ign:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Fetched 88.7 kB in 1s (61.7 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 7 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-430 linux-headers-4.15.0-76 linux-headers-4.15.0-76-generic
# Use 'apt autoremove' to remove them.
# The following NEW packages will be installed:
#   cuda-license-10-2 linux-headers-4.15.0-88 linux-headers-4.15.0-88-generic
# The following packages have been kept back:
#   libcudnn7 libcudnn7-dev libnccl-dev libnccl2
# The following packages will be upgraded:
#   libcublas-dev libcublas10 linux-headers-generic
# 3 upgraded, 3 newly installed, 0 to remove and 4 not upgraded.
# Need to get 96.6 MB of archives.
# After this operation, 99.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-4.15.0-88 all 4.15.0-88.88 [11.0 MB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-license-10-2 10.2.89-1 [16.4 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcublas10 10.2.2.89-1 [42.2 MB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-4.15.0-88-generic amd64 4.15.0-88.88 [1,127 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-generic amd64 4.15.0.88.80 [2,392 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcublas-dev 10.2.2.89-1 [42.3 MB]
# Fetched 96.6 MB in 2s (60.1 MB/s)
# Selecting previously unselected package cuda-license-10-2.
# (Reading database ... 148174 files and directories currently installed.)
# Preparing to unpack .../0-cuda-license-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-license-10-2 (10.2.89-1) ...
# Preparing to unpack .../1-libcublas10_10.2.2.89-1_amd64.deb ...
# Unpacking libcublas10 (10.2.2.89-1) over (10.2.1.243-1) ...
# Preparing to unpack .../2-libcublas-dev_10.2.2.89-1_amd64.deb ...
# Unpacking libcublas-dev (10.2.2.89-1) over (10.2.1.243-1) ...
# Selecting previously unselected package linux-headers-4.15.0-88.
# Preparing to unpack .../3-linux-headers-4.15.0-88_4.15.0-88.88_all.deb ...
# Unpacking linux-headers-4.15.0-88 (4.15.0-88.88) ...
# Selecting previously unselected package linux-headers-4.15.0-88-generic.
# Preparing to unpack .../4-linux-headers-4.15.0-88-generic_4.15.0-88.88_amd64.deb ...
# Unpacking linux-headers-4.15.0-88-generic (4.15.0-88.88) ...
# Preparing to unpack .../5-linux-headers-generic_4.15.0.88.80_amd64.deb ...
# Unpacking linux-headers-generic (4.15.0.88.80) over (4.15.0.76.78) ...
# Setting up linux-headers-4.15.0-88 (4.15.0-88.88) ...
# Setting up cuda-license-10-2 (10.2.89-1) ...
# *** LICENSE AGREEMENT ***
# By using this software you agree to fully comply with the terms and
# conditions of the EULA (End User License Agreement). The EULA is located
# at /usr/local/cuda-10.2/doc/EULA.txt. The EULA can also be found at
# http://docs.nvidia.com/cuda/eula/index.html. If you do not agree to the
# terms and conditions of the EULA, do not use the software.
#
# Setting up libcublas10 (10.2.2.89-1) ...
# Setting up libcublas-dev (10.2.2.89-1) ...
# Setting up linux-headers-4.15.0-88-generic (4.15.0-88.88) ...
# /etc/kernel/header_postinst.d/dkms:
#  * dkms: running auto installation service for kernel 4.15.0-88-generic
#
# Kernel preparation unnecessary for this kernel.  Skipping...
#
# Building module:
# cleaning build area...(bad exit status: 2)
# unset ARCH; [ ! -h /usr/bin/cc ] && export CC=/usr/bin/gcc; env NV_VERBOSE=1 'make' -j2 NV_EXCLUDE_BUILD_MODULES='' KERNEL_UNAME=4.15.0-88-generic IGNORE_XEN_PRESENCE=1 IGNORE_CC_MISMATCH=1 SYSSRC=/lib/modules/4.15.0-88-generic/build LD=/usr/bin/ld.bfd modules................................
# cleaning build area...(bad exit status: 2)
#
# DKMS: build completed.
#
# nvidia.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-88-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-88-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-88-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-88-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
#    ...done.
# Setting up linux-headers-generic (4.15.0.88.80) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
# %ls
# Out:
# 3rdparty/     CMakeLists.txt          include/                scripts/
# appveyor.yml  darknet*                json_mjpeg_streams.sh*  src/
# backup/       darknet53.conv.74       LICENSE                 valid.txt
# bad.list      DarknetConfig.cmake.in  Makefile                video_v2.sh*
# build/        darknet.py              net_cam_v3.sh*          video_yolov3.sh*
# build.ps1     darknet_video.py        obj/                    yolo-obj.cfg
# build.sh*     data/                   output.log
# cfg/          image_yolov2.sh*        README.md
# cmake/        image_yolov3.sh*        results/

# %%
# !./darknet detector test data/obj.data cfg/yolo-obj.cfg backup/yolo-obj_last.weights -ext_output -dont_show -out result.json < data/valid.txt
# Out:
#  CUDA-version: 10000 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  OpenCV isn't used
#  compute_capability = 750, cudnn_half = 1
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    3 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    5 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#    6 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#    7 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#    9 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   10 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#   12 conv    256       3 x 3/ 2    152 x 152 x 128 ->   76 x  76 x 256 3.407 BF
#   13 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   14 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   17 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   20 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   23 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   26 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   29 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   32 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   35 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     76 x  76 x 256 ->   38 x  38 x 512 3.407 BF
#   38 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   39 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   41 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   42 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   44 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   45 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   47 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   48 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   50 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   51 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   53 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   54 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   56 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   57 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   59 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   60 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   62 conv   1024       3 x 3/ 2     38 x  38 x 512 ->   19 x  19 x1024 3.407 BF
#   63 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   64 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   67 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   70 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   73 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   76 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   77 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   78 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   79 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   80 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   81 conv     18       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x  18 0.013 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   19 x  19 x 512
#   84 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   85 upsample                 2x    19 x  19 x 256 ->   38 x  38 x 256
#   86 route  85 61 	                           ->   38 x  38 x 768
#   87 conv    256       1 x 1/ 1     38 x  38 x 768 ->   38 x  38 x 256 0.568 BF
#   88 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   89 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   90 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   91 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   92 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   93 conv     18       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x  18 0.027 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   38 x  38 x 256
#   96 conv    128       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 128 0.095 BF
#   97 upsample                 2x    38 x  38 x 128 ->   76 x  76 x 128
#   98 route  97 36 	                           ->   76 x  76 x 384
#   99 conv    128       1 x 1/ 1     76 x  76 x 384 ->   76 x  76 x 128 0.568 BF
#  100 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  101 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  102 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  103 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  104 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  105 conv     18       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x  18 0.053 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 139.496
# avg_outputs = 1103769
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from backup/yolo-obj_last.weights...
#  seen 64, trained: 57 K-images (0 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
# Enter Image Path: data/img2/0.jpg: Predicted in 43.733000 milli-seconds.
# Enter Image Path: data/img2/1.jpg: Predicted in 43.514000 milli-seconds.
# Enter Image Path: data/img2/10.jpg: Predicted in 43.541000 milli-seconds.
# NumberPlate: 98%	(left_x:  461   top_y:  510   width:  776   height:  309)
# Enter Image Path: data/img2/100.jpg: Predicted in 43.677000 milli-seconds.
# NumberPlate: 77%	(left_x:  346   top_y:  323   width:  251   height:   59)
# Enter Image Path: data/img2/101.jpg: Predicted in 43.782000 milli-seconds.
# Enter Image Path: data/img2/102.jpg: Predicted in 43.626000 milli-seconds.
# NumberPlate: 83%	(left_x:  311   top_y:  512   width:  284   height:   73)
# Enter Image Path: data/img2/103.jpg: Predicted in 43.583000 milli-seconds.
# NumberPlate: 65%	(left_x:  308   top_y:  502   width:  242   height:   98)
# Enter Image Path: data/img2/104.jpg: Predicted in 43.673000 milli-seconds.
# NumberPlate: 84%	(left_x:  354   top_y:  515   width:  325   height:   77)
# NumberPlate: 36%	(left_x:  412   top_y:  542   width:  189   height:   40)
# Enter Image Path: data/img2/105.jpg: Predicted in 43.577000 milli-seconds.
# NumberPlate: 39%	(left_x:  113   top_y:  357   width:  113   height:   65)
# Enter Image Path: data/img2/106.jpg: Predicted in 43.650000 milli-seconds.
# NumberPlate: 89%	(left_x:  309   top_y:  378   width:  312   height:   74)
# Enter Image Path: data/img2/107.jpg: Predicted in 43.573000 milli-seconds.
# NumberPlate: 46%	(left_x:  759   top_y:  359   width:   67   height:   48)
# Enter Image Path: data/img2/108.jpg: Predicted in 43.511000 milli-seconds.
# NumberPlate: 92%	(left_x:  359   top_y:  483   width:  302   height:  129)
# Enter Image Path: data/img2/109.jpg: Predicted in 43.634000 milli-seconds.
# NumberPlate: 48%	(left_x:   42   top_y:  329   width:  105   height:  190)
# NumberPlate: 33%	(left_x:   57   top_y:  395   width:   79   height:   64)
# Enter Image Path: data/img2/11.jpg: Predicted in 43.616000 milli-seconds.
# NumberPlate: 63%	(left_x:  361   top_y:  276   width:  137   height:   20)
# Enter Image Path: data/img2/110.jpg: Predicted in 43.593000 milli-seconds.
# NumberPlate: 96%	(left_x:  198   top_y:  508   width:  478   height:   83)
# Enter Image Path: data/img2/111.jpg: Predicted in 43.682000 milli-seconds.
# NumberPlate: 55%	(left_x:  686   top_y:  446   width:   86   height:   88)
# Enter Image Path: data/img2/112.jpg: Predicted in 43.515000 milli-seconds.
# NumberPlate: 32%	(left_x:  315   top_y:  558   width:  262   height:   41)
# Enter Image Path: data/img2/113.jpg: Predicted in 43.683000 milli-seconds.
# NumberPlate: 79%	(left_x:  141   top_y:  326   width:  120   height:   79)
# Enter Image Path: data/img2/114.jpg: Predicted in 43.521000 milli-seconds.
# NumberPlate: 51%	(left_x:  400   top_y:  372   width:  260   height:  101)
# Enter Image Path: data/img2/115.jpg: Predicted in 43.683000 milli-seconds.
# NumberPlate: 32%	(left_x:  111   top_y:  326   width:  172   height:  137)
# Enter Image Path: data/img2/116.jpg: Predicted in 43.593000 milli-seconds.
# Enter Image Path: data/img2/117.jpg: Predicted in 43.560000 milli-seconds.
# NumberPlate: 94%	(left_x:  365   top_y:  481   width:  309   height:   76)
# NumberPlate: 61%	(left_x:  406   top_y:  504   width:  201   height:   37)
# Enter Image Path: data/img2/118.jpg: Predicted in 44.254000 milli-seconds.
# NumberPlate: 40%	(left_x:   53   top_y:  352   width:  147   height:   77)
# Enter Image Path: data/img2/119.jpg: Predicted in 43.494000 milli-seconds.
# NumberPlate: 100%	(left_x:  221   top_y:  371   width:  473   height:   59)
# Enter Image Path: data/img2/12.jpg: Predicted in 43.647000 milli-seconds.
# NumberPlate: 44%	(left_x:  790   top_y:  491   width:   79   height:   44)
# Enter Image Path: data/img2/120.jpg: Predicted in 43.559000 milli-seconds.
# NumberPlate: 64%	(left_x:  700   top_y:  368   width:   66   height:   77)
# Enter Image Path: data/img2/121.jpg: Predicted in 43.640000 milli-seconds.
# NumberPlate: 89%	(left_x:  321   top_y:  510   width:  288   height:   85)
# Enter Image Path: data/img2/122.jpg: Predicted in 43.504000 milli-seconds.
# NumberPlate: 29%	(left_x:  109   top_y:  454   width:   88   height:   65)
# Enter Image Path: data/img2/123.jpg: Predicted in 44.016000 milli-seconds.
# NumberPlate: 81%	(left_x:  244   top_y:  513   width:  451   height:   73)
# Enter Image Path: data/img2/124.jpg: Predicted in 43.610000 milli-seconds.
# Enter Image Path: data/img2/125.jpg: Predicted in 43.629000 milli-seconds.
# NumberPlate: 44%	(left_x:  696   top_y:  435   width:  143   height:   90)
# Enter Image Path: data/img2/126.jpg: Predicted in 43.632000 milli-seconds.
# NumberPlate: 71%	(left_x:  378   top_y:  505   width:  246   height:   83)
# Enter Image Path: data/img2/127.jpg: Predicted in 43.595000 milli-seconds.
# NumberPlate: 67%	(left_x:  148   top_y:  403   width:   90   height:   46)
# Enter Image Path: data/img2/128.jpg: Predicted in 43.553000 milli-seconds.
# NumberPlate: 77%	(left_x:  360   top_y:  439   width:  266   height:   32)
# NumberPlate: 38%	(left_x:  433   top_y:  431   width:  122   height:   41)
# Enter Image Path: data/img2/129.jpg: Predicted in 43.545000 milli-seconds.
# NumberPlate: 65%	(left_x:  608   top_y:  445   width:  107   height:   46)
# Enter Image Path: data/img2/13.jpg: Predicted in 43.480000 milli-seconds.
# NumberPlate: 26%	(left_x:  385   top_y:  193   width:  180   height:   37)
# NumberPlate: 61%	(left_x:  426   top_y:  140   width:   99   height:  163)
# Enter Image Path: data/img2/130.jpg: Predicted in 43.549000 milli-seconds.
# NumberPlate: 86%	(left_x:  274   top_y:  526   width:  325   height:   55)
# Enter Image Path: data/img2/131.jpg: Predicted in 43.528000 milli-seconds.
# NumberPlate: 92%	(left_x:  288   top_y:  356   width:  286   height:  100)
# Enter Image Path: data/img2/132.jpg: Predicted in 43.752000 milli-seconds.
# NumberPlate: 89%	(left_x:  744   top_y:  351   width:   77   height:   67)
# Enter Image Path: data/img2/133.jpg: Predicted in 43.561000 milli-seconds.
# NumberPlate: 56%	(left_x:  379   top_y:  391   width:  207   height:  231)
# Enter Image Path: data/img2/134.jpg: Predicted in 43.650000 milli-seconds.
# NumberPlate: 95%	(left_x:  348   top_y:  502   width:  174   height:   37)
# Enter Image Path: data/img2/135.jpg: Predicted in 43.487000 milli-seconds.
# NumberPlate: 94%	(left_x:  807   top_y:  333   width:   85   height:   63)
# Enter Image Path: data/img2/136.jpg: Predicted in 43.607000 milli-seconds.
# NumberPlate: 93%	(left_x:  290   top_y:  445   width:  335   height:   92)
# Enter Image Path: data/img2/137.jpg: Predicted in 43.501000 milli-seconds.
# NumberPlate: 97%	(left_x:  221   top_y:  484   width:  108   height:   48)
# Enter Image Path: data/img2/138.jpg: Predicted in 43.582000 milli-seconds.
# NumberPlate: 95%	(left_x:  739   top_y:  367   width:   82   height:   42)
# Enter Image Path: data/img2/139.jpg: Predicted in 43.965000 milli-seconds.
# NumberPlate: 96%	(left_x:   74   top_y:  475   width:   97   height:   42)
# NumberPlate: 43%	(left_x:   93   top_y:  472   width:   51   height:   37)
# Enter Image Path: data/img2/14.jpg: Predicted in 43.470000 milli-seconds.
# NumberPlate: 99%	(left_x:  202   top_y:  191   width:  236   height:   42)
# Enter Image Path: data/img2/140.jpg: Predicted in 43.661000 milli-seconds.
# NumberPlate: 43%	(left_x:  601   top_y:  453   width:   82   height:   31)
# Enter Image Path: data/img2/141.jpg: Predicted in 43.605000 milli-seconds.
# Enter Image Path: data/img2/15.jpg: Predicted in 43.565000 milli-seconds.
# NumberPlate: 98%	(left_x:  347   top_y:  302   width:   87   height:   20)
# Enter Image Path: data/img2/16.jpg: Predicted in 43.595000 milli-seconds.
# NumberPlate: 78%	(left_x:  352   top_y:  258   width:  105   height:   24)
# Enter Image Path: data/img2/17.jpg: Predicted in 43.681000 milli-seconds.
# NumberPlate: 76%	(left_x:  256   top_y:  268   width:  127   height:   24)
# Enter Image Path: data/img2/18.jpg: Predicted in 43.603000 milli-seconds.
# NumberPlate: 93%	(left_x:  306   top_y:  215   width:   64   height:   17)
# Enter Image Path: data/img2/19.jpg: Predicted in 43.642000 milli-seconds.
# NumberPlate: 95%	(left_x:  194   top_y:  314   width:  248   height:   55)
# Enter Image Path: data/img2/2.jpg: Predicted in 43.633000 milli-seconds.
# Enter Image Path: data/img2/20.jpg: Predicted in 43.661000 milli-seconds.
# NumberPlate: 96%	(left_x:  396   top_y:  145   width:  118   height:   53)
# Enter Image Path: data/img2/21.jpg: Predicted in 43.690000 milli-seconds.
# NumberPlate: 97%	(left_x:  511   top_y:  384   width:   85   height:   32)
# Enter Image Path: data/img2/22.jpg: Predicted in 43.461000 milli-seconds.
# NumberPlate: 50%	(left_x:  503   top_y:  187   width:   37   height:  180)
# Enter Image Path: data/img2/23.jpg: Predicted in 43.620000 milli-seconds.
# NumberPlate: 41%	(left_x:  267   top_y:  415   width:  182   height:   37)
# Enter Image Path: data/img2/24.jpg: Predicted in 43.485000 milli-seconds.
# NumberPlate: 33%	(left_x:  411   top_y:  362   width:  170   height:   46)
# NumberPlate: 84%	(left_x:  413   top_y:  340   width:  186   height:   93)
# Enter Image Path: data/img2/25.jpg: Predicted in 43.561000 milli-seconds.
# NumberPlate: 71%	(left_x:  256   top_y:  412   width:  137   height:   27)
# Enter Image Path: data/img2/26.jpg: Predicted in 43.562000 milli-seconds.
# NumberPlate: 95%	(left_x:  252   top_y:  363   width:  200   height:   42)
# Enter Image Path: data/img2/27.jpg: Predicted in 43.705000 milli-seconds.
# NumberPlate: 82%	(left_x:  279   top_y:  266   width:  123   height:   32)
# Enter Image Path: data/img2/28.jpg: Predicted in 43.532000 milli-seconds.
# NumberPlate: 47%	(left_x:  177   top_y:  179   width:  139   height:   52)
# NumberPlate: 31%	(left_x:  198   top_y:  190   width:   92   height:   26)
# Enter Image Path: data/img2/29.jpg: Predicted in 43.636000 milli-seconds.
# NumberPlate: 52%	(left_x:  520   top_y:  225   width:  118   height:   49)
# Enter Image Path: data/img2/3.jpg: Predicted in 43.718000 milli-seconds.
# NumberPlate: 90%	(left_x: 1401   top_y: 3514   width:  775   height:  133)
# Enter Image Path: data/img2/30.jpg: Predicted in 43.543000 milli-seconds.
# NumberPlate: 68%	(left_x:   59   top_y:  240   width:  117   height:  100)
# NumberPlate: 32%	(left_x:   86   top_y:  273   width:   67   height:   42)
# Enter Image Path: data/img2/31.jpg: Predicted in 43.674000 milli-seconds.
# NumberPlate: 93%	(left_x:  300   top_y:  370   width:  105   height:   20)
# Enter Image Path: data/img2/32.jpg: Predicted in 43.542000 milli-seconds.
# NumberPlate: 98%	(left_x:  130   top_y:  342   width:  205   height:  103)
# Enter Image Path: data/img2/33.jpg: Predicted in 43.740000 milli-seconds.
# NumberPlate: 62%	(left_x:  259   top_y:  364   width:  141   height:   17)
# Enter Image Path: data/img2/34.jpg: Predicted in 43.623000 milli-seconds.
# NumberPlate: 97%	(left_x:  226   top_y:  366   width:  258   height:   44)
# Enter Image Path: data/img2/35.jpg: Predicted in 43.649000 milli-seconds.
# NumberPlate: 99%	(left_x:  215   top_y:  280   width:  292   height:   58)
# Enter Image Path: data/img2/36.jpg: Predicted in 43.701000 milli-seconds.
# Enter Image Path: data/img2/37.jpg: Predicted in 43.519000 milli-seconds.
# NumberPlate: 77%	(left_x:  329   top_y:  218   width:   85   height:   13)
# Enter Image Path: data/img2/38.jpg: Predicted in 43.534000 milli-seconds.
# NumberPlate: 98%	(left_x:  267   top_y:  303   width:  105   height:   19)
# Enter Image Path: data/img2/39.jpg: Predicted in 43.530000 milli-seconds.
# NumberPlate: 71%	(left_x:  180   top_y:  346   width:  297   height:  121)
# Enter Image Path: data/img2/4.jpg: Predicted in 43.681000 milli-seconds.
# NumberPlate: 61%	(left_x:  604   top_y:  271   width:  217   height:   91)
# NumberPlate: 86%	(left_x:  635   top_y:  290   width:  146   height:   46)
# Enter Image Path: data/img2/40.jpg: Predicted in 43.609000 milli-seconds.
# NumberPlate: 76%	(left_x:  334   top_y:  334   width:  105   height:   12)
# Enter Image Path: data/img2/41.jpg: Predicted in 43.554000 milli-seconds.
# NumberPlate: 60%	(left_x:  211   top_y:  268   width:  154   height:   59)
# Enter Image Path: data/img2/42.jpg: Predicted in 43.534000 milli-seconds.
# Enter Image Path: data/img2/43.jpg: Predicted in 43.693000 milli-seconds.
# NumberPlate: 96%	(left_x:  296   top_y:  308   width:  103   height:   21)
# Enter Image Path: data/img2/44.jpg: Predicted in 43.599000 milli-seconds.
# NumberPlate: 28%	(left_x:  171   top_y:  280   width:  148   height:   50)
# NumberPlate: 91%	(left_x:  185   top_y:  298   width:  109   height:   25)
# Enter Image Path: data/img2/45.jpg: Predicted in 43.570000 milli-seconds.
# NumberPlate: 40%	(left_x:  261   top_y:  275   width:  186   height:   39)
# NumberPlate: 90%	(left_x:  293   top_y:  287   width:  120   height:   21)
# Enter Image Path: data/img2/46.jpg: Predicted in 43.511000 milli-seconds.
# NumberPlate: 79%	(left_x:  266   top_y:  295   width:  148   height:   13)
# NumberPlate: 64%	(left_x:  300   top_y:  291   width:   77   height:   18)
# Enter Image Path: data/img2/47.jpg: Predicted in 43.778000 milli-seconds.
# NumberPlate: 57%	(left_x:  396   top_y:  251   width:  150   height:   46)
# NumberPlate: 81%	(left_x:  426   top_y:  263   width:   83   height:   27)
# Enter Image Path: data/img2/48.jpg: Predicted in 43.512000 milli-seconds.
# Enter Image Path: data/img2/49.jpg: Predicted in 43.667000 milli-seconds.
# NumberPlate: 70%	(left_x:  161   top_y:  425   width:  105   height:   36)
# Enter Image Path: data/img2/5.jpg: Predicted in 43.737000 milli-seconds.
# NumberPlate: 84%	(left_x: 1212   top_y: 2115   width:  546   height:  196)
# Enter Image Path: data/img2/50.jpg: Predicted in 43.511000 milli-seconds.
# NumberPlate: 72%	(left_x:  291   top_y:  238   width:  105   height:   28)
# NumberPlate: 35%	(left_x:  304   top_y:  243   width:   84   height:   16)
# Enter Image Path: data/img2/51.jpg: Predicted in 43.609000 milli-seconds.
# NumberPlate: 100%	(left_x:  281   top_y:  352   width:  215   height:   72)
# Enter Image Path: data/img2/52.jpg: Predicted in 43.600000 milli-seconds.
# NumberPlate: 39%	(left_x:  367   top_y:  278   width:  205   height:   95)
# Enter Image Path: data/img2/53.jpg: Predicted in 43.549000 milli-seconds.
# NumberPlate: 90%	(left_x:  277   top_y:  375   width:  132   height:   30)
# Enter Image Path: data/img2/54.jpg: Predicted in 43.652000 milli-seconds.
# Enter Image Path: data/img2/55.jpg: Predicted in 43.630000 milli-seconds.
# NumberPlate: 84%	(left_x:  524   top_y:  291   width:   60   height:   43)
# Enter Image Path: data/img2/56.jpg: Predicted in 43.593000 milli-seconds.
# NumberPlate: 55%	(left_x:  257   top_y:  392   width:  215   height:   81)
# Enter Image Path: data/img2/57.jpg: Predicted in 43.587000 milli-seconds.
# NumberPlate: 90%	(left_x:   97   top_y:  276   width:  163   height:   82)
# Enter Image Path: data/img2/58.jpg: Predicted in 43.554000 milli-seconds.
# NumberPlate: 99%	(left_x:  191   top_y:  364   width:  252   height:   43)
# Enter Image Path: data/img2/59.jpg: Predicted in 43.653000 milli-seconds.
# NumberPlate: 81%	(left_x:  268   top_y:  320   width:  102   height:   18)
# Enter Image Path: data/img2/6.jpg: Predicted in 44.354000 milli-seconds.
# NumberPlate: 88%	(left_x:  443   top_y:  627   width:  162   height:   47)
# Enter Image Path: data/img2/60.jpg: Predicted in 43.550000 milli-seconds.
# NumberPlate: 96%	(left_x:   84   top_y:  301   width:  181   height:  110)
# Enter Image Path: data/img2/61.jpg: Predicted in 43.535000 milli-seconds.
# NumberPlate: 31%	(left_x:  139   top_y:  131   width:  143   height:   56)
# NumberPlate: 75%	(left_x:  164   top_y:  143   width:   86   height:   33)
# Enter Image Path: data/img2/62.jpg: Predicted in 43.625000 milli-seconds.
# NumberPlate: 93%	(left_x:  360   top_y:  353   width:  124   height:   27)
# Enter Image Path: data/img2/63.jpg: Predicted in 43.620000 milli-seconds.
# NumberPlate: 86%	(left_x:  273   top_y:  228   width:   96   height:   23)
# Enter Image Path: data/img2/64.jpg: Predicted in 43.516000 milli-seconds.
# NumberPlate: 87%	(left_x:  243   top_y:  233   width:  117   height:   21)
# Enter Image Path: data/img2/65.jpg: Predicted in 43.677000 milli-seconds.
# NumberPlate: 71%	(left_x:  228   top_y:  214   width:  163   height:   38)
# Enter Image Path: data/img2/66.jpg: Predicted in 43.546000 milli-seconds.
# NumberPlate: 84%	(left_x:  170   top_y:  268   width:  153   height:   22)
# Enter Image Path: data/img2/67.jpg: Predicted in 43.617000 milli-seconds.
# NumberPlate: 30%	(left_x:  -13   top_y:   48   width:   88   height:   89)
# NumberPlate: 43%	(left_x:  522   top_y:  311   width:   86   height:   22)
# NumberPlate: 26%	(left_x:  540   top_y:  296   width:   40   height:   51)
# Enter Image Path: data/img2/68.jpg: Predicted in 43.623000 milli-seconds.
# NumberPlate: 98%	(left_x:  266   top_y:  309   width:  112   height:   22)
# Enter Image Path: data/img2/69.jpg: Predicted in 43.631000 milli-seconds.
# NumberPlate: 98%	(left_x:  452   top_y:  157   width:   64   height:   31)
# Enter Image Path: data/img2/7.jpg: Predicted in 43.692000 milli-seconds.
# NumberPlate: 59%	(left_x: 1056   top_y: 1675   width:  722   height:  158)
# Enter Image Path: data/img2/70.jpg: Predicted in 43.634000 milli-seconds.
# NumberPlate: 81%	(left_x:  523   top_y:  316   width:  107   height:  125)
# Enter Image Path: data/img2/71.jpg: Predicted in 43.587000 milli-seconds.
# NumberPlate: 98%	(left_x:  189   top_y:  359   width:  255   height:   49)
# Enter Image Path: data/img2/72.jpg: Predicted in 43.619000 milli-seconds.
# NumberPlate: 51%	(left_x:  231   top_y:  203   width:  198   height:   59)
# Enter Image Path: data/img2/73.jpg: Predicted in 43.451000 milli-seconds.
# NumberPlate: 60%	(left_x:  119   top_y:  370   width:  140   height:   27)
# Enter Image Path: data/img2/74.jpg: Predicted in 43.562000 milli-seconds.
# NumberPlate: 91%	(left_x:  264   top_y:  232   width:   58   height:   17)
# Enter Image Path: data/img2/75.jpg: Predicted in 43.596000 milli-seconds.
# NumberPlate: 93%	(left_x:  537   top_y:  246   width:  121   height:   75)
# Enter Image Path: data/img2/76.jpg: Predicted in 43.556000 milli-seconds.
# NumberPlate: 95%	(left_x:  443   top_y:  187   width:   44   height:   28)
# Enter Image Path: data/img2/77.jpg: Predicted in 43.532000 milli-seconds.
# NumberPlate: 96%	(left_x:  271   top_y:  243   width:   93   height:   21)
# Enter Image Path: data/img2/78.jpg: Predicted in 43.520000 milli-seconds.
# NumberPlate: 98%	(left_x:  185   top_y:  386   width:  228   height:   49)
# Enter Image Path: data/img2/79.jpg: Predicted in 43.528000 milli-seconds.
# NumberPlate: 35%	(left_x:  265   top_y:  266   width:  199   height:  117)
# Enter Image Path: data/img2/8.jpg: Predicted in 43.765000 milli-seconds.
# Enter Image Path: data/img2/80.jpg: Predicted in 43.726000 milli-seconds.
# NumberPlate: 95%	(left_x:  318   top_y:  299   width:  101   height:   26)
# Enter Image Path: data/img2/81.jpg: Predicted in 43.599000 milli-seconds.
# NumberPlate: 98%	(left_x:  218   top_y:  313   width:  100   height:   22)
# Enter Image Path: data/img2/82.jpg: Predicted in 43.659000 milli-seconds.
# NumberPlate: 92%	(left_x:  272   top_y:  258   width:  176   height:   58)
# Enter Image Path: data/img2/83.jpg: Predicted in 43.498000 milli-seconds.
# NumberPlate: 98%	(left_x:  279   top_y:  336   width:  120   height:   20)
# Enter Image Path: data/img2/84.jpg: Predicted in 43.501000 milli-seconds.
# NumberPlate: 98%	(left_x:  287   top_y:  346   width:   98   height:   18)
# Enter Image Path: data/img2/85.jpg: Predicted in 43.501000 milli-seconds.
# NumberPlate: 86%	(left_x:  465   top_y:  284   width:   55   height:   31)
# Enter Image Path: data/img2/86.jpg: Predicted in 43.438000 milli-seconds.
# NumberPlate: 98%	(left_x:  286   top_y:  335   width:  139   height:   21)
# Enter Image Path: data/img2/87.jpg: Predicted in 43.451000 milli-seconds.
# NumberPlate: 75%	(left_x:  372   top_y:  164   width:   86   height:   34)
# Enter Image Path: data/img2/88.jpg: Predicted in 43.714000 milli-seconds.
# NumberPlate: 98%	(left_x:  374   top_y:  295   width:  111   height:   18)
# Enter Image Path: data/img2/89.jpg: Predicted in 43.439000 milli-seconds.
# NumberPlate: 96%	(left_x:  275   top_y:  408   width:  187   height:   59)
# Enter Image Path: data/img2/9.jpg: Predicted in 43.477000 milli-seconds.
# NumberPlate: 98%	(left_x:  376   top_y:  244   width:  133   height:   27)
# Enter Image Path: data/img2/90.jpg: Predicted in 43.534000 milli-seconds.
# Enter Image Path: data/img2/91.jpg: Predicted in 43.488000 milli-seconds.
# NumberPlate: 36%	(left_x:  216   top_y:  296   width:   51   height:   18)
# Enter Image Path: data/img2/92.jpg: Predicted in 43.609000 milli-seconds.
# NumberPlate: 90%	(left_x:  268   top_y:  339   width:  251   height:   49)
# Enter Image Path: data/img2/93.jpg: Predicted in 43.466000 milli-seconds.
# NumberPlate: 65%	(left_x:  167   top_y:  335   width:  142   height:   50)
# Enter Image Path: data/img2/94.jpg: Predicted in 43.606000 milli-seconds.
# NumberPlate: 98%	(left_x:  315   top_y:  316   width:  103   height:   15)
# Enter Image Path: data/img2/95.jpg: Predicted in 43.629000 milli-seconds.
# NumberPlate: 43%	(left_x:  515   top_y:  309   width:  130   height:  152)
# Enter Image Path: data/img2/96.jpg: Predicted in 43.607000 milli-seconds.
# NumberPlate: 88%	(left_x:  301   top_y:  313   width:   99   height:   19)
# Enter Image Path: data/img2/97.jpg: Predicted in 43.633000 milli-seconds.
# NumberPlate: 83%	(left_x:  261   top_y:  274   width:   74   height:   19)
# Enter Image Path: data/img2/98.jpg: Predicted in 43.445000 milli-seconds.
# NumberPlate: 46%	(left_x:   51   top_y:  347   width:   61   height:   88)
# Enter Image Path: data/img2/99.jpg: Predicted in 43.749000 milli-seconds.
# NumberPlate: 56%	(left_x:  254   top_y:  383   width:  213   height:   33)
# Enter Image Path:
